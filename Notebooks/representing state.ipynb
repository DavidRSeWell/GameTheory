# %% [markdown]
# ## Representing the information state as a vector

# %% [markdown]
# In order to take advantage of deep reinforcement learning in the context of finding NE solutions to games of imperfect information we need to be able to represent the state the a player finds himself in at any given time. Because of the asymmetry of poker this needs to include the necessary information leading up to the given state that is capable of differentiating that state from another since in poker that are a lot of ways to arrive at any given state and how you got there matters.

# %%
# For the AKQ game we are actually going to first ignore prior actions because there is only one way 
# to get to any given state. So the state can easily be represented as the vector player x node x hand
# So

# %%
from IPython.display import Image

# %%
Image(filename='/Users/befeltingu/GameTheory/Results/Poker/MCTS/img/akq_extended.png')

# %%
player_1 = [1,0]
player_2 = [0,1]

# %%
info_0 = player_1 + [1,0,0,0,0] + [1,0,0]

# %%
info_0
# Out:
# [1, 0, 1, 0, 0, 0, 0, 1, 0, 0]
